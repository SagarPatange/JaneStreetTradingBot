# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# ------------------------------
# 1. Feature Engineering
# ------------------------------

# Load data
data_dir = "/Users/abdur-rahmanibn-bilalwaajid/jane_street_project/data/train.parquet"
features_file = "/Users/abdur-rahmanibn-bilalwaajid/jane_street_project/data/features.csv"

# Step 1: Load features.csv to identify all features
features_df = pd.read_csv(features_file)
all_features = features_df["feature"].tolist()

# Include target column and load data for a manageable partition
selected_features = all_features + ["responder_6"]
df = pd.read_parquet(f"{data_dir}/partition_id=0", engine="pyarrow", columns=selected_features).head(50000)

# Step 2: Handle missing values
df.fillna(0, inplace=True)  # Replace NaN values with 0

# Step 3: Feature Variance Threshold (remove low-variance features)
X = df.drop(columns=["responder_6"]).values
y = df["responder_6"].values

# Remove low-variance features
variance_threshold = VarianceThreshold(threshold=0.01)  # Adjust threshold as needed
X_high_variance = variance_threshold.fit_transform(X)

# Step 4: Scale Features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_high_variance)

# Step 5: Dimensionality Reduction using PCA
pca = PCA(n_components=0.95)  # Retain 95% variance
X_pca = pca.fit_transform(X_scaled)

print(f"Original features: {X.shape[1]}, After Variance Threshold: {X_high_variance.shape[1]}, After PCA: {X_pca.shape[1]}")

# ------------------------------
# 2. Train/Test Split
# ------------------------------
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# ------------------------------
# 3. Define MLP Model
# ------------------------------

# Improved MLP architecture
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='linear')  # Output layer
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mae'])

# ------------------------------
# 4. Train the Model
# ------------------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,  # Increase epochs as needed
    batch_size=64,  # Adjust batch size based on available memory
    verbose=1
)

# ------------------------------
# 5. Evaluate the Model
# ------------------------------
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")

# ------------------------------
# 6. Visualization
# ------------------------------

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)
plt.show()

# Plot PCA explained variance ratio
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_)
plt.title('Explained Variance by PCA Components')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()
# Out:
# Original features: 79, After Variance Threshold: 70, After PCA: 40
# Epoch 1/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6692 - mae: 0.5663 - val_loss: 0.5777 - val_mae: 0.5254
# Epoch 2/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.6239 - mae: 0.5445 - val_loss: 0.5595 - val_mae: 0.5169
# Epoch 3/100
# 625/625 [==============================] - 2s 4ms/step - loss: 0.6053 - mae: 0.5363 - val_loss: 0.5449 - val_mae: 0.5113
# Epoch 4/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.5901 - mae: 0.5326 - val_loss: 0.5242 - val_mae: 0.5029
# Epoch 5/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.5705 - mae: 0.5264 - val_loss: 0.5125 - val_mae: 0.4988
# Epoch 6/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.5551 - mae: 0.5217 - val_loss: 0.4929 - val_mae: 0.4908
# Epoch 7/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5392 - mae: 0.5155 - val_loss: 0.4782 - val_mae: 0.4862
# Epoch 8/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.5268 - mae: 0.5108 - val_loss: 0.4773 - val_mae: 0.4829
# Epoch 9/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.5166 - mae: 0.5080 - val_loss: 0.4677 - val_mae: 0.4817
# Epoch 10/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.5081 - mae: 0.5051 - val_loss: 0.4575 - val_mae: 0.4771
# Epoch 11/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4962 - mae: 0.4995 - val_loss: 0.4489 - val_mae: 0.4721
# Epoch 12/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4954 - mae: 0.4994 - val_loss: 0.4481 - val_mae: 0.4723
# Epoch 13/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4820 - mae: 0.4936 - val_loss: 0.4441 - val_mae: 0.4708
# Epoch 14/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4738 - mae: 0.4912 - val_loss: 0.4306 - val_mae: 0.4655
# Epoch 15/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4666 - mae: 0.4870 - val_loss: 0.4305 - val_mae: 0.4640
# Epoch 16/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4614 - mae: 0.4847 - val_loss: 0.4244 - val_mae: 0.4616
# Epoch 17/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4540 - mae: 0.4835 - val_loss: 0.4191 - val_mae: 0.4593
# Epoch 18/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4528 - mae: 0.4819 - val_loss: 0.4162 - val_mae: 0.4593
# Epoch 19/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4454 - mae: 0.4795 - val_loss: 0.4129 - val_mae: 0.4570
# Epoch 20/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4419 - mae: 0.4767 - val_loss: 0.4020 - val_mae: 0.4528
# Epoch 21/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4390 - mae: 0.4774 - val_loss: 0.4042 - val_mae: 0.4533
# Epoch 22/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4318 - mae: 0.4734 - val_loss: 0.4083 - val_mae: 0.4543
# Epoch 23/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4320 - mae: 0.4728 - val_loss: 0.3985 - val_mae: 0.4503
# Epoch 24/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4251 - mae: 0.4702 - val_loss: 0.3923 - val_mae: 0.4472
# Epoch 25/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4237 - mae: 0.4702 - val_loss: 0.3914 - val_mae: 0.4462
# Epoch 26/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4234 - mae: 0.4693 - val_loss: 0.3929 - val_mae: 0.4471
# Epoch 27/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4207 - mae: 0.4687 - val_loss: 0.3991 - val_mae: 0.4494
# Epoch 28/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.4189 - mae: 0.4664 - val_loss: 0.3953 - val_mae: 0.4469
# Epoch 29/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4141 - mae: 0.4644 - val_loss: 0.3921 - val_mae: 0.4469
# Epoch 30/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.4154 - mae: 0.4655 - val_loss: 0.3873 - val_mae: 0.4445
# Epoch 31/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4103 - mae: 0.4621 - val_loss: 0.3871 - val_mae: 0.4445
# Epoch 32/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4139 - mae: 0.4651 - val_loss: 0.3798 - val_mae: 0.4417
# Epoch 33/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4027 - mae: 0.4596 - val_loss: 0.3862 - val_mae: 0.4451
# Epoch 34/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4042 - mae: 0.4609 - val_loss: 0.3759 - val_mae: 0.4381
# Epoch 35/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.4041 - mae: 0.4581 - val_loss: 0.3810 - val_mae: 0.4407
# Epoch 36/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3992 - mae: 0.4577 - val_loss: 0.3656 - val_mae: 0.4339
# Epoch 37/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3979 - mae: 0.4581 - val_loss: 0.3893 - val_mae: 0.4443
# Epoch 38/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3939 - mae: 0.4547 - val_loss: 0.3724 - val_mae: 0.4392
# Epoch 39/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3929 - mae: 0.4549 - val_loss: 0.3825 - val_mae: 0.4391
# Epoch 40/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3982 - mae: 0.4572 - val_loss: 0.3743 - val_mae: 0.4381
# Epoch 41/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3925 - mae: 0.4539 - val_loss: 0.3750 - val_mae: 0.4370
# Epoch 42/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3922 - mae: 0.4536 - val_loss: 0.3732 - val_mae: 0.4377
# Epoch 43/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3857 - mae: 0.4510 - val_loss: 0.3665 - val_mae: 0.4337
# Epoch 44/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3883 - mae: 0.4519 - val_loss: 0.3770 - val_mae: 0.4377
# Epoch 45/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3896 - mae: 0.4525 - val_loss: 0.3727 - val_mae: 0.4347
# Epoch 46/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3862 - mae: 0.4514 - val_loss: 0.3706 - val_mae: 0.4355
# Epoch 47/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3821 - mae: 0.4492 - val_loss: 0.3713 - val_mae: 0.4354
# Epoch 48/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3859 - mae: 0.4514 - val_loss: 0.3696 - val_mae: 0.4343
# Epoch 49/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3773 - mae: 0.4472 - val_loss: 0.3737 - val_mae: 0.4374
# Epoch 50/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3812 - mae: 0.4484 - val_loss: 0.3638 - val_mae: 0.4316
# Epoch 51/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3809 - mae: 0.4483 - val_loss: 0.3683 - val_mae: 0.4336
# Epoch 52/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3795 - mae: 0.4476 - val_loss: 0.3766 - val_mae: 0.4372
# Epoch 53/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3759 - mae: 0.4465 - val_loss: 0.3704 - val_mae: 0.4344
# Epoch 54/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3767 - mae: 0.4459 - val_loss: 0.3663 - val_mae: 0.4323
# Epoch 55/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3755 - mae: 0.4457 - val_loss: 0.3679 - val_mae: 0.4334
# Epoch 56/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3745 - mae: 0.4442 - val_loss: 0.3627 - val_mae: 0.4321
# Epoch 57/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3685 - mae: 0.4427 - val_loss: 0.3624 - val_mae: 0.4312
# Epoch 58/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3704 - mae: 0.4438 - val_loss: 0.3586 - val_mae: 0.4290
# Epoch 59/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3733 - mae: 0.4434 - val_loss: 0.3613 - val_mae: 0.4300
# Epoch 60/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3692 - mae: 0.4431 - val_loss: 0.3647 - val_mae: 0.4314
# Epoch 61/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3682 - mae: 0.4419 - val_loss: 0.3646 - val_mae: 0.4311
# Epoch 62/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3715 - mae: 0.4444 - val_loss: 0.3665 - val_mae: 0.4310
# Epoch 63/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3701 - mae: 0.4440 - val_loss: 0.3667 - val_mae: 0.4309
# Epoch 64/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3671 - mae: 0.4420 - val_loss: 0.3622 - val_mae: 0.4305
# Epoch 65/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3649 - mae: 0.4410 - val_loss: 0.3598 - val_mae: 0.4288
# Epoch 66/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3642 - mae: 0.4401 - val_loss: 0.3623 - val_mae: 0.4302
# Epoch 67/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3661 - mae: 0.4409 - val_loss: 0.3628 - val_mae: 0.4293
# Epoch 68/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3625 - mae: 0.4386 - val_loss: 0.3573 - val_mae: 0.4268
# Epoch 69/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3666 - mae: 0.4405 - val_loss: 0.3598 - val_mae: 0.4291
# Epoch 70/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3646 - mae: 0.4399 - val_loss: 0.3550 - val_mae: 0.4285
# Epoch 71/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3569 - mae: 0.4360 - val_loss: 0.3632 - val_mae: 0.4300
# Epoch 72/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3608 - mae: 0.4389 - val_loss: 0.3667 - val_mae: 0.4314
# Epoch 73/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3586 - mae: 0.4366 - val_loss: 0.3628 - val_mae: 0.4285
# Epoch 74/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3625 - mae: 0.4390 - val_loss: 0.3627 - val_mae: 0.4294
# Epoch 75/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3615 - mae: 0.4384 - val_loss: 0.3634 - val_mae: 0.4293
# Epoch 76/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3591 - mae: 0.4375 - val_loss: 0.3612 - val_mae: 0.4281
# Epoch 77/100
# 625/625 [==============================] - 2s 2ms/step - loss: 0.3610 - mae: 0.4374 - val_loss: 0.3630 - val_mae: 0.4293
# Epoch 78/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3606 - mae: 0.4374 - val_loss: 0.3659 - val_mae: 0.4316
# Epoch 79/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3591 - mae: 0.4369 - val_loss: 0.3589 - val_mae: 0.4280
# Epoch 80/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3621 - mae: 0.4372 - val_loss: 0.3589 - val_mae: 0.4286
# Epoch 81/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3542 - mae: 0.4348 - val_loss: 0.3597 - val_mae: 0.4270
# Epoch 82/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3576 - mae: 0.4375 - val_loss: 0.3636 - val_mae: 0.4302
# Epoch 83/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3605 - mae: 0.4372 - val_loss: 0.3577 - val_mae: 0.4283
# Epoch 84/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3603 - mae: 0.4376 - val_loss: 0.3625 - val_mae: 0.4299
# Epoch 85/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3577 - mae: 0.4360 - val_loss: 0.3595 - val_mae: 0.4292
# Epoch 86/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3578 - mae: 0.4361 - val_loss: 0.3518 - val_mae: 0.4234
# Epoch 87/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3539 - mae: 0.4343 - val_loss: 0.3522 - val_mae: 0.4235
# Epoch 88/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3575 - mae: 0.4355 - val_loss: 0.3702 - val_mae: 0.4332
# Epoch 89/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3562 - mae: 0.4354 - val_loss: 0.3561 - val_mae: 0.4266
# Epoch 90/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3512 - mae: 0.4322 - val_loss: 0.3521 - val_mae: 0.4243
# Epoch 91/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3566 - mae: 0.4353 - val_loss: 0.3611 - val_mae: 0.4302
# Epoch 92/100
# 625/625 [==============================] - 2s 3ms/step - loss: 0.3552 - mae: 0.4354 - val_loss: 0.3584 - val_mae: 0.4272
# Epoch 93/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3518 - mae: 0.4338 - val_loss: 0.3542 - val_mae: 0.4244
# Epoch 94/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3516 - mae: 0.4338 - val_loss: 0.3606 - val_mae: 0.4274
# Epoch 95/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3503 - mae: 0.4323 - val_loss: 0.3606 - val_mae: 0.4271
# Epoch 96/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3474 - mae: 0.4321 - val_loss: 0.3595 - val_mae: 0.4272
# Epoch 97/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3516 - mae: 0.4326 - val_loss: 0.3553 - val_mae: 0.4259
# Epoch 98/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3467 - mae: 0.4310 - val_loss: 0.3566 - val_mae: 0.4269
# Epoch 99/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3480 - mae: 0.4311 - val_loss: 0.3562 - val_mae: 0.4267
# Epoch 100/100
# 625/625 [==============================] - 1s 2ms/step - loss: 0.3502 - mae: 0.4328 - val_loss: 0.3526 - val_mae: 0.4235
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3526 - mae: 0.4235
# Test Loss: 0.3526, Test MAE: 0.4235

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

# ------------------------------
# 1. Load and Preprocess Data
# ------------------------------
# Load data
data_dir = "/Users/abdur-rahmanibn-bilalwaajid/jane_street_project/data/train.parquet"
features_file = "/Users/abdur-rahmanibn-bilalwaajid/jane_street_project/data/features.csv"

# Load features.csv to identify all features
features_df = pd.read_csv(features_file)
all_features = features_df["feature"].tolist()

# Include target column and load data
selected_features = all_features + ["responder_6"]
df = pd.read_parquet(f"{data_dir}/partition_id=0", engine="pyarrow", columns=selected_features).head(50000)

# Handle missing values
df.fillna(0, inplace=True)

# Feature variance threshold
X = df.drop(columns=["responder_6"]).values
y = df["responder_6"].values

variance_threshold = VarianceThreshold(threshold=0.01)
X_high_variance = variance_threshold.fit_transform(X)

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_high_variance)

# Dimensionality reduction with PCA
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)

print(f"Original features: {X.shape[1]}, After Variance Threshold: {X_high_variance.shape[1]}, After PCA: {X_pca.shape[1]}")

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# ------------------------------
# 2. Define Custom R² Loss
# ------------------------------
def weighted_r2_loss(y_true, y_pred):
    weights = tf.abs(y_true)
    numerator = tf.reduce_sum(weights * tf.square(y_true - y_pred))
    denominator = tf.reduce_sum(weights * tf.square(y_true))
    return numerator / denominator

def r2_score_metric(y_true, y_pred):
    weights = tf.abs(y_true)
    numerator = tf.reduce_sum(weights * tf.square(y_true - y_pred))
    denominator = tf.reduce_sum(weights * tf.square(y_true))
    return 1 - numerator / denominator

# ------------------------------
# 3. Define Optimized MLP Model
# ------------------------------
model = Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.4),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(1, activation='linear')  # Output layer
])

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=weighted_r2_loss,
    metrics=[r2_score_metric]
)

# ------------------------------
# 4. Callbacks for Optimization
# ------------------------------
# Reduce learning rate on plateau
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1
)

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True, verbose=1
)

# ------------------------------
# 5. Train the Model
# ------------------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=64,
    callbacks=[reduce_lr, early_stopping],
    verbose=1
)

# ------------------------------
# 6. Evaluate the Model
# ------------------------------
test_loss, test_r2 = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test R² Score: {test_r2:.4f}")

# ------------------------------
# 7. Visualization
# ------------------------------
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation R² score
plt.figure(figsize=(10, 6))
plt.plot(history.history['r2_score_metric'], label='Training R² Score')
plt.plot(history.history['val_r2_score_metric'], label='Validation R² Score')
plt.title('Training and Validation R² Score')
plt.xlabel('Epochs')
plt.ylabel('R² Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Original features: 79, After Variance Threshold: 70, After PCA: 40
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x161be3eb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/var/folders/2g/lvx0dpq95g197k18lll6c4hr0000gn/T/__autograph_generated_file6doa5j41.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x161be3eb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/var/folders/2g/lvx0dpq95g197k18lll6c4hr0000gn/T/__autograph_generated_file6doa5j41.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2025-01-07 23:27:53.911952: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:AutoGraph could not transform <function weighted_r2_loss at 0x161ac0b80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/var/folders/2g/lvx0dpq95g197k18lll6c4hr0000gn/T/__autograph_generated_file4hkcc4pm.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function weighted_r2_loss at 0x161ac0b80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: [Errno 28] No space left on device: '/var/folders/2g/lvx0dpq95g197k18lll6c4hr0000gn/T/__autograph_generated_file4hkcc4pm.py'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 625/625 [==============================] - 5s 6ms/step - loss: 1.4262 - r2_score_metric: -0.4262 - val_loss: 0.8937 - val_r2_score_metric: 0.1053 - lr: 0.0010
# Epoch 2/100
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0049 - r2_score_metric: -0.0049 - val_loss: 0.8614 - val_r2_score_metric: 0.1375 - lr: 0.0010
# Epoch 3/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9102 - r2_score_metric: 0.0898 - val_loss: 0.8177 - val_r2_score_metric: 0.1816 - lr: 0.0010
# Epoch 4/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.8701 - r2_score_metric: 0.1299 - val_loss: 0.7861 - val_r2_score_metric: 0.2138 - lr: 0.0010
# Epoch 5/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8361 - r2_score_metric: 0.1639 - val_loss: 0.7590 - val_r2_score_metric: 0.2407 - lr: 0.0010
# Epoch 6/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.8029 - r2_score_metric: 0.1971 - val_loss: 0.7386 - val_r2_score_metric: 0.2613 - lr: 0.0010
# Epoch 7/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7616 - r2_score_metric: 0.2384 - val_loss: 0.6987 - val_r2_score_metric: 0.3022 - lr: 0.0010
# Epoch 8/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7417 - r2_score_metric: 0.2583 - val_loss: 0.6838 - val_r2_score_metric: 0.3169 - lr: 0.0010
# Epoch 9/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7054 - r2_score_metric: 0.2946 - val_loss: 0.6417 - val_r2_score_metric: 0.3590 - lr: 0.0010
# Epoch 10/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6848 - r2_score_metric: 0.3152 - val_loss: 0.6287 - val_r2_score_metric: 0.3716 - lr: 0.0010
# Epoch 11/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6824 - r2_score_metric: 0.3176 - val_loss: 0.5972 - val_r2_score_metric: 0.4039 - lr: 0.0010
# Epoch 12/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6414 - r2_score_metric: 0.3586 - val_loss: 0.6033 - val_r2_score_metric: 0.3977 - lr: 0.0010
# Epoch 13/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6360 - r2_score_metric: 0.3640 - val_loss: 0.5740 - val_r2_score_metric: 0.4268 - lr: 0.0010
# Epoch 14/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6139 - r2_score_metric: 0.3861 - val_loss: 0.5607 - val_r2_score_metric: 0.4399 - lr: 0.0010
# Epoch 15/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6079 - r2_score_metric: 0.3921 - val_loss: 0.5559 - val_r2_score_metric: 0.4448 - lr: 0.0010
# Epoch 16/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6040 - r2_score_metric: 0.3960 - val_loss: 0.5520 - val_r2_score_metric: 0.4487 - lr: 0.0010
# Epoch 17/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5767 - r2_score_metric: 0.4233 - val_loss: 0.5237 - val_r2_score_metric: 0.4772 - lr: 0.0010
# Epoch 18/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.5713 - r2_score_metric: 0.4287 - val_loss: 0.5005 - val_r2_score_metric: 0.5002 - lr: 0.0010
# Epoch 19/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5607 - r2_score_metric: 0.4393 - val_loss: 0.4908 - val_r2_score_metric: 0.5098 - lr: 0.0010
# Epoch 20/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5478 - r2_score_metric: 0.4522 - val_loss: 0.4817 - val_r2_score_metric: 0.5189 - lr: 0.0010
# Epoch 21/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5541 - r2_score_metric: 0.4459 - val_loss: 0.4943 - val_r2_score_metric: 0.5062 - lr: 0.0010
# Epoch 22/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5291 - r2_score_metric: 0.4709 - val_loss: 0.4854 - val_r2_score_metric: 0.5151 - lr: 0.0010
# Epoch 23/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5268 - r2_score_metric: 0.4732 - val_loss: 0.4655 - val_r2_score_metric: 0.5347 - lr: 0.0010
# Epoch 24/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5174 - r2_score_metric: 0.4826 - val_loss: 0.4550 - val_r2_score_metric: 0.5455 - lr: 0.0010
# Epoch 25/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5192 - r2_score_metric: 0.4808 - val_loss: 0.4624 - val_r2_score_metric: 0.5383 - lr: 0.0010
# Epoch 26/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4990 - r2_score_metric: 0.5010 - val_loss: 0.4533 - val_r2_score_metric: 0.5469 - lr: 0.0010
# Epoch 27/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.5110 - r2_score_metric: 0.4890 - val_loss: 0.4379 - val_r2_score_metric: 0.5620 - lr: 0.0010
# Epoch 28/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4985 - r2_score_metric: 0.5015 - val_loss: 0.4481 - val_r2_score_metric: 0.5521 - lr: 0.0010
# Epoch 29/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4938 - r2_score_metric: 0.5062 - val_loss: 0.4394 - val_r2_score_metric: 0.5609 - lr: 0.0010
# Epoch 30/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4782 - r2_score_metric: 0.5218 - val_loss: 0.4244 - val_r2_score_metric: 0.5756 - lr: 0.0010
# Epoch 31/100
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4860 - r2_score_metric: 0.5141 - val_loss: 0.4472 - val_r2_score_metric: 0.5527 - lr: 0.0010
# Epoch 32/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4872 - r2_score_metric: 0.5128 - val_loss: 0.4187 - val_r2_score_metric: 0.5811 - lr: 0.0010
# Epoch 33/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4733 - r2_score_metric: 0.5267 - val_loss: 0.4252 - val_r2_score_metric: 0.5747 - lr: 0.0010
# Epoch 34/100
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4750 - r2_score_metric: 0.5250 - val_loss: 0.4133 - val_r2_score_metric: 0.5867 - lr: 0.0010
# Epoch 35/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.4603 - r2_score_metric: 0.5397 - val_loss: 0.3964 - val_r2_score_metric: 0.6037 - lr: 0.0010
# Epoch 36/100
# 625/625 [==============================] - 5s 8ms/step - loss: 0.4620 - r2_score_metric: 0.5380 - val_loss: 0.4022 - val_r2_score_metric: 0.5979 - lr: 0.0010
# Epoch 37/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.4610 - r2_score_metric: 0.5390 - val_loss: 0.3989 - val_r2_score_metric: 0.6011 - lr: 0.0010
# Epoch 38/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4552 - r2_score_metric: 0.5448 - val_loss: 0.4002 - val_r2_score_metric: 0.5999 - lr: 0.0010
# Epoch 39/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.4555 - r2_score_metric: 0.5445 - val_loss: 0.4064 - val_r2_score_metric: 0.5935 - lr: 0.0010
# Epoch 40/100
# 613/625 [============================>.] - ETA: 0s - loss: 0.4647 - r2_score_metric: 0.5353
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4654 - r2_score_metric: 0.5346 - val_loss: 0.4061 - val_r2_score_metric: 0.5938 - lr: 0.0010
# Epoch 41/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4373 - r2_score_metric: 0.5627 - val_loss: 0.3916 - val_r2_score_metric: 0.6082 - lr: 5.0000e-04
# Epoch 42/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4309 - r2_score_metric: 0.5691 - val_loss: 0.3891 - val_r2_score_metric: 0.6107 - lr: 5.0000e-04
# Epoch 43/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4202 - r2_score_metric: 0.5798 - val_loss: 0.3848 - val_r2_score_metric: 0.6152 - lr: 5.0000e-04
# Epoch 44/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.4167 - r2_score_metric: 0.5833 - val_loss: 0.3879 - val_r2_score_metric: 0.6120 - lr: 5.0000e-04
# Epoch 45/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4208 - r2_score_metric: 0.5792 - val_loss: 0.3850 - val_r2_score_metric: 0.6148 - lr: 5.0000e-04
# Epoch 46/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4161 - r2_score_metric: 0.5839 - val_loss: 0.3824 - val_r2_score_metric: 0.6175 - lr: 5.0000e-04
# Epoch 47/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4167 - r2_score_metric: 0.5833 - val_loss: 0.3758 - val_r2_score_metric: 0.6242 - lr: 5.0000e-04
# Epoch 48/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4169 - r2_score_metric: 0.5831 - val_loss: 0.3695 - val_r2_score_metric: 0.6303 - lr: 5.0000e-04
# Epoch 49/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4156 - r2_score_metric: 0.5844 - val_loss: 0.3680 - val_r2_score_metric: 0.6319 - lr: 5.0000e-04
# Epoch 50/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.4079 - r2_score_metric: 0.5921 - val_loss: 0.3725 - val_r2_score_metric: 0.6274 - lr: 5.0000e-04
# Epoch 51/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.4041 - r2_score_metric: 0.5959 - val_loss: 0.3692 - val_r2_score_metric: 0.6310 - lr: 5.0000e-04
# Epoch 52/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3939 - r2_score_metric: 0.6061 - val_loss: 0.3638 - val_r2_score_metric: 0.6362 - lr: 5.0000e-04
# Epoch 53/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.4058 - r2_score_metric: 0.5942 - val_loss: 0.3634 - val_r2_score_metric: 0.6365 - lr: 5.0000e-04
# Epoch 54/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3990 - r2_score_metric: 0.6010 - val_loss: 0.3611 - val_r2_score_metric: 0.6388 - lr: 5.0000e-04
# Epoch 55/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.4018 - r2_score_metric: 0.5982 - val_loss: 0.3560 - val_r2_score_metric: 0.6439 - lr: 5.0000e-04
# Epoch 56/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3893 - r2_score_metric: 0.6107 - val_loss: 0.3578 - val_r2_score_metric: 0.6421 - lr: 5.0000e-04
# Epoch 57/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3991 - r2_score_metric: 0.6009 - val_loss: 0.3572 - val_r2_score_metric: 0.6428 - lr: 5.0000e-04
# Epoch 58/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3942 - r2_score_metric: 0.6058 - val_loss: 0.3535 - val_r2_score_metric: 0.6466 - lr: 5.0000e-04
# Epoch 59/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3889 - r2_score_metric: 0.6111 - val_loss: 0.3506 - val_r2_score_metric: 0.6494 - lr: 5.0000e-04
# Epoch 60/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3936 - r2_score_metric: 0.6064 - val_loss: 0.3522 - val_r2_score_metric: 0.6479 - lr: 5.0000e-04
# Epoch 61/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3983 - r2_score_metric: 0.6017 - val_loss: 0.3596 - val_r2_score_metric: 0.6404 - lr: 5.0000e-04
# Epoch 62/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3924 - r2_score_metric: 0.6076 - val_loss: 0.3482 - val_r2_score_metric: 0.6518 - lr: 5.0000e-04
# Epoch 63/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3914 - r2_score_metric: 0.6086 - val_loss: 0.3467 - val_r2_score_metric: 0.6532 - lr: 5.0000e-04
# Epoch 64/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3884 - r2_score_metric: 0.6116 - val_loss: 0.3483 - val_r2_score_metric: 0.6516 - lr: 5.0000e-04
# Epoch 65/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3876 - r2_score_metric: 0.6124 - val_loss: 0.3503 - val_r2_score_metric: 0.6495 - lr: 5.0000e-04
# Epoch 66/100
# 625/625 [==============================] - 3s 6ms/step - loss: 0.3887 - r2_score_metric: 0.6113 - val_loss: 0.3486 - val_r2_score_metric: 0.6512 - lr: 5.0000e-04
# Epoch 67/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3934 - r2_score_metric: 0.6066 - val_loss: 0.3553 - val_r2_score_metric: 0.6446 - lr: 5.0000e-04
# Epoch 68/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3822 - r2_score_metric: 0.6178 - val_loss: 0.3465 - val_r2_score_metric: 0.6533 - lr: 5.0000e-04
# Epoch 69/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3763 - r2_score_metric: 0.6237 - val_loss: 0.3465 - val_r2_score_metric: 0.6533 - lr: 5.0000e-04
# Epoch 70/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3873 - r2_score_metric: 0.6127 - val_loss: 0.3450 - val_r2_score_metric: 0.6550 - lr: 5.0000e-04
# Epoch 71/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3840 - r2_score_metric: 0.6160 - val_loss: 0.3401 - val_r2_score_metric: 0.6596 - lr: 5.0000e-04
# Epoch 72/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3848 - r2_score_metric: 0.6152 - val_loss: 0.3496 - val_r2_score_metric: 0.6504 - lr: 5.0000e-04
# Epoch 73/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3795 - r2_score_metric: 0.6205 - val_loss: 0.3411 - val_r2_score_metric: 0.6589 - lr: 5.0000e-04
# Epoch 74/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3838 - r2_score_metric: 0.6162 - val_loss: 0.3383 - val_r2_score_metric: 0.6617 - lr: 5.0000e-04
# Epoch 75/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3768 - r2_score_metric: 0.6232 - val_loss: 0.3316 - val_r2_score_metric: 0.6684 - lr: 5.0000e-04
# Epoch 76/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3760 - r2_score_metric: 0.6240 - val_loss: 0.3398 - val_r2_score_metric: 0.6601 - lr: 5.0000e-04
# Epoch 77/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3782 - r2_score_metric: 0.6218 - val_loss: 0.3406 - val_r2_score_metric: 0.6593 - lr: 5.0000e-04
# Epoch 78/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3769 - r2_score_metric: 0.6231 - val_loss: 0.3422 - val_r2_score_metric: 0.6578 - lr: 5.0000e-04
# Epoch 79/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3754 - r2_score_metric: 0.6246 - val_loss: 0.3426 - val_r2_score_metric: 0.6573 - lr: 5.0000e-04
# Epoch 80/100
# 625/625 [==============================] - ETA: 0s - loss: 0.3777 - r2_score_metric: 0.6223
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3777 - r2_score_metric: 0.6223 - val_loss: 0.3406 - val_r2_score_metric: 0.6593 - lr: 5.0000e-04
# Epoch 81/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3698 - r2_score_metric: 0.6302 - val_loss: 0.3353 - val_r2_score_metric: 0.6646 - lr: 2.5000e-04
# Epoch 82/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3648 - r2_score_metric: 0.6352 - val_loss: 0.3328 - val_r2_score_metric: 0.6671 - lr: 2.5000e-04
# Epoch 83/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3576 - r2_score_metric: 0.6424 - val_loss: 0.3321 - val_r2_score_metric: 0.6678 - lr: 2.5000e-04
# Epoch 84/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3635 - r2_score_metric: 0.6365 - val_loss: 0.3300 - val_r2_score_metric: 0.6699 - lr: 2.5000e-04
# Epoch 85/100
# 625/625 [==============================] - 6s 9ms/step - loss: 0.3593 - r2_score_metric: 0.6407 - val_loss: 0.3307 - val_r2_score_metric: 0.6692 - lr: 2.5000e-04
# Epoch 86/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3620 - r2_score_metric: 0.6380 - val_loss: 0.3302 - val_r2_score_metric: 0.6696 - lr: 2.5000e-04
# Epoch 87/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3520 - r2_score_metric: 0.6480 - val_loss: 0.3324 - val_r2_score_metric: 0.6675 - lr: 2.5000e-04
# Epoch 88/100
# 625/625 [==============================] - 5s 7ms/step - loss: 0.3571 - r2_score_metric: 0.6429 - val_loss: 0.3323 - val_r2_score_metric: 0.6675 - lr: 2.5000e-04
# Epoch 89/100
# 617/625 [============================>.] - ETA: 0s - loss: 0.3607 - r2_score_metric: 0.6393
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 625/625 [==============================] - 5s 8ms/step - loss: 0.3601 - r2_score_metric: 0.6399 - val_loss: 0.3348 - val_r2_score_metric: 0.6649 - lr: 2.5000e-04
# Epoch 90/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3583 - r2_score_metric: 0.6417 - val_loss: 0.3299 - val_r2_score_metric: 0.6698 - lr: 1.2500e-04
# Epoch 91/100
# 625/625 [==============================] - 3s 5ms/step - loss: 0.3584 - r2_score_metric: 0.6416 - val_loss: 0.3275 - val_r2_score_metric: 0.6723 - lr: 1.2500e-04
# Epoch 92/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3569 - r2_score_metric: 0.6431 - val_loss: 0.3251 - val_r2_score_metric: 0.6746 - lr: 1.2500e-04
# Epoch 93/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3535 - r2_score_metric: 0.6465 - val_loss: 0.3249 - val_r2_score_metric: 0.6748 - lr: 1.2500e-04
# Epoch 94/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3504 - r2_score_metric: 0.6496 - val_loss: 0.3251 - val_r2_score_metric: 0.6747 - lr: 1.2500e-04
# Epoch 95/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3447 - r2_score_metric: 0.6553 - val_loss: 0.3233 - val_r2_score_metric: 0.6766 - lr: 1.2500e-04
# Epoch 96/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3473 - r2_score_metric: 0.6527 - val_loss: 0.3263 - val_r2_score_metric: 0.6736 - lr: 1.2500e-04
# Epoch 97/100
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3504 - r2_score_metric: 0.6496 - val_loss: 0.3270 - val_r2_score_metric: 0.6728 - lr: 1.2500e-04
# Epoch 98/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3541 - r2_score_metric: 0.6459 - val_loss: 0.3299 - val_r2_score_metric: 0.6700 - lr: 1.2500e-04
# Epoch 99/100
# 625/625 [==============================] - 4s 6ms/step - loss: 0.3439 - r2_score_metric: 0.6561 - val_loss: 0.3243 - val_r2_score_metric: 0.6756 - lr: 1.2500e-04
# Epoch 100/100
# 620/625 [============================>.] - ETA: 0s - loss: 0.3454 - r2_score_metric: 0.6546
# Epoch 100: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 625/625 [==============================] - 4s 7ms/step - loss: 0.3452 - r2_score_metric: 0.6548 - val_loss: 0.3253 - val_r2_score_metric: 0.6745 - lr: 1.2500e-04
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3634 - r2_score_metric: 0.6366
# Test Loss: 0.3634, Test R² Score: 0.6366
